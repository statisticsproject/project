# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dt_train = pd.read_csv("data_train.csv")

# %%
dt_train.head()
# Out:
#    OrderId  StoreId  ...  EstimatedOrderCompletionTime  ActualOrderCompletionTime
# 0        0      152  ...                         808.0                      411.0
# 1        1      152  ...                         791.0                      394.0
# 2        2      152  ...                         803.0                      352.0
# 3        3      152  ...                         825.0                      401.0
# 4        4      152  ...                         826.0                      392.0
#
# [5 rows x 16 columns]

# %%
model_q1a = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue \
                + OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + DriversClockedIn \
                + DriversOnTheWay + ClockedInEmployees', data=dt_train).fit()
print(model_q1a.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     ActualOrderCompletionTime   R-squared:                       0.107
# Model:                                   OLS   Adj. R-squared:                  0.107
# Method:                        Least Squares   F-statistic:                     1985.
# Date:                       Sat, 17 Oct 2020   Prob (F-statistic):               0.00
# Time:                               15:39:41   Log-Likelihood:            -1.2933e+06
# No. Observations:                     148416   AIC:                         2.587e+06
# Df Residuals:                         148406   BIC:                         2.587e+06
# Df Model:                                  9
# Covariance Type:                   nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               1897.8458     15.056    126.053      0.000    1868.336    1927.355
# OrderPrice                14.8892      0.352     42.279      0.000      14.199      15.579
# DeliveryType            -478.9046      6.787    -70.566      0.000    -492.206    -465.603
# OrdersInQueue             99.0007      1.641     60.318      0.000      95.784     102.218
# OvenProductsInQueue       -0.3965      0.044     -8.916      0.000      -0.484      -0.309
# OrdersInOven              41.1189      3.244     12.675      0.000      34.760      47.477
# OrdersReadyForDispatch    66.4578      2.171     30.607      0.000      62.202      70.714
# DriversClockedIn          10.3950      3.341      3.111      0.002       3.846      16.944
# DriversOnTheWay           52.0469      2.670     19.494      0.000      46.814      57.280
# ClockedInEmployees       -38.6193      2.528    -15.274      0.000     -43.575     -33.664
# ==============================================================================
# Omnibus:                   229670.995   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        170721876.670
# Skew:                           9.757   Prob(JB):                         0.00
# Kurtosis:                     168.004   Cond. No.                         515.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model_q1a.predict(dt_train)
# Out:
# 0         1044.111822
# 1         1142.716040
# 2          990.007750
# 3          991.561743
# 4         1025.831641
#              ...
# 148426    1295.616556
# 148427    2327.660303
# 148428    1563.615454
# 148429    2065.618898
# 148430            NaN
# Length: 148431, dtype: float64

# %%
predictions_q1a = model_q1a.predict(dt_train)

# %%
dt_train['Predicted_ActualOrderCompletionTime'] = predictions_q1a

# %%
dt_train[["ActualOrderCompletionTime", "Predicted_ActualOrderCompletionTime"]].head()
# Out:
#    ActualOrderCompletionTime  Predicted_ActualOrderCompletionTime
# 0                      411.0                          1044.111822
# 1                      394.0                          1142.716040
# 2                      352.0                           990.007750
# 3                      401.0                           991.561743
# 4                      392.0                          1025.831641

# %%
dt_train["error"] = dt_train["ActualOrderCompletionTime"] - dt_train["Predicted_ActualOrderCompletionTime"]

# %%
dt_train[["ActualOrderCompletionTime", "Predicted_ActualOrderCompletionTime", "error"]].head()
# Out:
#    ActualOrderCompletionTime  Predicted_ActualOrderCompletionTime       error
# 0                      411.0                          1044.111822 -633.111822
# 1                      394.0                          1142.716040 -748.716040
# 2                      352.0                           990.007750 -638.007750
# 3                      401.0                           991.561743 -590.561743
# 4                      392.0                          1025.831641 -633.831641

# %%
dt_train["error_abs"] = np.abs(dt_train["error"])

# %%
dt_train[["ActualOrderCompletionTime", "Predicted_ActualOrderCompletionTime", "error", "error_abs"]].head()
# Out:
#    ActualOrderCompletionTime  ...   error_abs
# 0                      411.0  ...  633.111822
# 1                      394.0  ...  748.716040
# 2                      352.0  ...  638.007750
# 3                      401.0  ...  590.561743
# 4                      392.0  ...  633.831641
#
# [5 rows x 4 columns]

# %%
dt_train["error_abs"].mean()
# Out:
# 713.467326219674

# %%
dt_train["error_squared"] = dt_train["error"]**2

# %%
dt_train[["ActualOrderCompletionTime", "Predicted_ActualOrderCompletionTime", "error", "error_abs", "error_squared"]].head()
# Out:
#    ActualOrderCompletionTime  ...  error_squared
# 0                      411.0  ...  400830.579173
# 1                      394.0  ...  560575.708422
# 2                      352.0  ...  407053.889397
# 3                      401.0  ...  348763.172598
# 4                      392.0  ...  401742.548720
#
# [5 rows x 5 columns]

# %%
dt_train["error_squared"].mean()
# Out:
# 2169463.6589179146

# %%
np.sqrt(dt_train["error_squared"].mean())
# Out:
# 1472.9099289901994

# %%
dt_train["error2"] = dt_train["ActualOrderCompletionTime"] - dt_train["EstimatedOrderCompletionTime"]

# %%
dt_train[["ActualOrderCompletionTime", "EstimatedOrderCompletionTime", "error2"]].head()
# Out:
#    ActualOrderCompletionTime  EstimatedOrderCompletionTime  error2
# 0                      411.0                         808.0  -397.0
# 1                      394.0                         791.0  -397.0
# 2                      352.0                         803.0  -451.0
# 3                      401.0                         825.0  -424.0
# 4                      392.0                         826.0  -434.0

# %%
dt_train["error2_abs"] = np.abs(dt_train["error2"])

# %%
dt_train["error2_abs"].mean()
# Out:
# 666.2914173673997

# %%
dt_train["error2_squared"] = dt_train["error2"]**2

# %%
np.sqrt(dt_train["error2_squared"].mean())
# Out:
# 1492.3667019107322

# %%
dt_train[["ActualOrderCompletionTime", "EstimatedOrderCompletionTime", "error2", "error2_abs", "error2_squared"]].head()
# Out:
#    ActualOrderCompletionTime  ...  error2_squared
# 0                      411.0  ...        157609.0
# 1                      394.0  ...        157609.0
# 2                      352.0  ...        203401.0
# 3                      401.0  ...        179776.0
# 4                      392.0  ...        188356.0
#
# [5 rows x 5 columns]

# %%
dt_train[["error_abs", "error2_abs"]].iloc[:10]
# Out:
#      error_abs  error2_abs
# 0   633.111822       397.0
# 1   748.716040       397.0
# 2   638.007750       451.0
# 3   590.561743       424.0
# 4   633.831641       434.0
# 5  1377.198171      1282.0
# 6   259.226514       417.0
# 7   468.262960       506.0
# 8   513.171912       688.0
# 9   360.141336       270.0

# %%
data_fit = dt_train[dt_train["ReceivedTimestamp"]<"2018-09-01 00:00:00"]

# %%
data_val_fit = dt_train[dt_train["ReceivedTimestamp"]>="2018-09-01 00:00:00"]

# %%
data_fit["ReceivedTimestamp"].head()
# Out:
# Series([], Name: ReceivedTimestamp, dtype: object)

# %%
data_val_fit["ReceivedTimestamp"].head()
# Out:
# 0    6/1/2018 13:35
# 1    6/1/2018 13:35
# 2    6/1/2018 15:38
# 3    6/1/2018 15:59
# 4    6/1/2018 16:04
# Name: ReceivedTimestamp, dtype: object

# %%
model_q1b = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue \
                + OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + DriversClockedIn \
                + DriversOnTheWay + ClockedInEmployees', data=dt_train).fit()
print(model_q1b.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     ActualOrderCompletionTime   R-squared:                       0.107
# Model:                                   OLS   Adj. R-squared:                  0.107
# Method:                        Least Squares   F-statistic:                     1985.
# Date:                       Sat, 17 Oct 2020   Prob (F-statistic):               0.00
# Time:                               15:39:42   Log-Likelihood:            -1.2933e+06
# No. Observations:                     148416   AIC:                         2.587e+06
# Df Residuals:                         148406   BIC:                         2.587e+06
# Df Model:                                  9
# Covariance Type:                   nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               1897.8458     15.056    126.053      0.000    1868.336    1927.355
# OrderPrice                14.8892      0.352     42.279      0.000      14.199      15.579
# DeliveryType            -478.9046      6.787    -70.566      0.000    -492.206    -465.603
# OrdersInQueue             99.0007      1.641     60.318      0.000      95.784     102.218
# OvenProductsInQueue       -0.3965      0.044     -8.916      0.000      -0.484      -0.309
# OrdersInOven              41.1189      3.244     12.675      0.000      34.760      47.477
# OrdersReadyForDispatch    66.4578      2.171     30.607      0.000      62.202      70.714
# DriversClockedIn          10.3950      3.341      3.111      0.002       3.846      16.944
# DriversOnTheWay           52.0469      2.670     19.494      0.000      46.814      57.280
# ClockedInEmployees       -38.6193      2.528    -15.274      0.000     -43.575     -33.664
# ==============================================================================
# Omnibus:                   229670.995   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        170721876.670
# Skew:                           9.757   Prob(JB):                         0.00
# Kurtosis:                     168.004   Cond. No.                         515.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
predictions_q1b = model_q1b.predict(data_val_fit)

# %%
data_val_fit["predictions_q1b"] = predictions_q1b
data_val_fit["error_q1b"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q1b"]
data_val_fit["error_q1b_abs"] = np.abs(data_val_fit["error_q1b"])

# %%
data_val_fit["error_q1b_abs"].mean()
# Out:
# 713.467326219674

# %%
data_val_fit["error_q1b_sqr"] = data_val_fit["error_q1b"]**2

# %%
np.sqrt(data_val_fit["error_q1b_sqr"].mean())
# Out:
# 1472.9099289901994

# %%
data_val_fit["error2_abs"].mean()
# Out:
# 666.2914173673997

# %%
np.sqrt(data_val_fit["error2_squared"].mean())
# Out:
# 1492.3667019107322

# %%
# removed DriversClockedIn
model_q2 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + \
                    DriversOnTheWay + ClockedInEmployees', data=dt_train).fit()

# %%
predictions_q2 = model_q2.predict(data_val_fit)
data_val_fit["predictions_q2"] = predictions_q2
data_val_fit["error_q2"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q2"]
data_val_fit["error_q2_abs"] = np.abs(data_val_fit["error_q2"])
data_val_fit["error_q2_sqr"] = data_val_fit["error_q2"] ** 2
print(data_val_fit["error_q2_abs"].mean(), np.sqrt(data_val_fit["error_q2_sqr"].mean()))
# Out:
# 713.444331988986 1472.9579612398713

# %%
# removed DriversClockedIn
# removed ClockedInEmployees
model_q2 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + \
                    DriversOnTheWay', data=dt_train).fit()

# %%
predictions_q2 = model_q2.predict(data_val_fit)
data_val_fit["predictions_q2"] = predictions_q2
data_val_fit["error_q2"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q2"]
data_val_fit["error_q2_abs"] = np.abs(data_val_fit["error_q2"])
data_val_fit["error_q2_sqr"] = data_val_fit["error_q2"] ** 2
print(data_val_fit["error_q2_abs"].mean(), np.sqrt(data_val_fit["error_q2_sqr"].mean()))
# Out:
# 716.240004489836 1475.221784787834

# %%
# change delivery type
data_val_fit["DeliveryType"].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: DeliveryType, dtype: int64

# %%
data_fit["DeliveryType_str"] = data_fit["DeliveryType"].astype(str)
data_val_fit["DeliveryType_str"] = data_val_fit["DeliveryType"].astype(str)

# %%
data_val_fit["DeliveryType_str"].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: DeliveryType_str, dtype: object

# %%
# removed DriversClockedIn
# Bring back ClockedInEmployees
# change delivery type to string
model_q2 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + \
                    DriversOnTheWay + ClockedInEmployees', data=dt_train).fit()

predictions_q2 = model_q2.predict(data_val_fit)
data_val_fit["predictions_q2"] = predictions_q2
data_val_fit["error_q2"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q2"]
data_val_fit["error_q2_abs"] = np.abs(data_val_fit["error_q2"])
data_val_fit["error_q2_sqr"] = data_val_fit["error_q2"] ** 2
print(data_val_fit["error_q2_abs"].mean(), np.sqrt(data_val_fit["error_q2_sqr"].mean()))
# Out:
# 713.444331988986 1472.9579612398713

# %%
data_val_fit["StoreId"].head()
# Out:
# 0    152
# 1    152
# 2    152
# 3    152
# 4    152
# Name: StoreId, dtype: int64

# %%
# removed DriversClockedIn
# Bring back ClockedInEmployees
# change delivery type to string
# Add StoreId
model_q2 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + \
                    DriversOnTheWay + ClockedInEmployees + StoreId', data=dt_train).fit()

predictions_q2 = model_q2.predict(data_val_fit)
data_val_fit["predictions_q2"] = predictions_q2
data_val_fit["error_q2"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q2"]
data_val_fit["error_q2_abs"] = np.abs(data_val_fit["error_q2"])
data_val_fit["error_q2_sqr"] = data_val_fit["error_q2"] ** 2
print(data_val_fit["error_q2_abs"].mean(), np.sqrt(data_val_fit["error_q2_sqr"].mean()))
# Out:
# 708.7251541237434 1470.7454925286468

# %%
data_fit["StoreId_str"] = data_fit["StoreId"].astype(str)
data_val_fit["StoreId_str"] = data_val_fit["StoreId"].astype(str)

# %%
# removed DriversClockedIn
# Bring back ClockedInEmployees
# change delivery type to string
# Add StoreId, changed to string 

model_q2 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + \
                    DriversOnTheWay + ClockedInEmployees + StoreId', data=dt_train).fit()

predictions_q2 = model_q2.predict(data_val_fit)
data_val_fit["predictions_q2"] = predictions_q2
data_val_fit["error_q2"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q2"]
data_val_fit["error_q2_abs"] = np.abs(data_val_fit["error_q2"])
data_val_fit["error_q2_sqr"] = data_val_fit["error_q2"] ** 2
print(data_val_fit["error_q2_abs"].mean(), np.sqrt(data_val_fit["error_q2_sqr"].mean()))
# Out:
# 708.7251541237434 1470.7454925286468

# %%
data_fit.iloc[:10]
# Out:
# Empty DataFrame
# Columns: [OrderId, StoreId, OrderPrice, DeliveryType, OrdersInQueue, OvenProductsInQueue, OrdersInOven, OrdersReadyForDispatch, DriversClockedIn, DriversOnTheWay, ClockedInEmployees, ReceivedTimestamp, CompletedTimestamp, OriginalEstimatedDrivingTimeSeconds, EstimatedOrderCompletionTime, ActualOrderCompletionTime, Predicted_ActualOrderCompletionTime, error, error_abs, error_squared, error2, error2_abs, error2_squared, DeliveryType_str, StoreId_str]
# Index: []

# %%
data_val_fit["OrdersInQueue"].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: OrdersInQueue, dtype: int64

# %%
data_val_fit["OrdersInQueue"].describe()
# Out:
# count    148430.000000
# mean          1.968894
# std           2.992855
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          35.000000
# Name: OrdersInQueue, dtype: float64

# %%
data_fit["OrdersInQueue_plus1"] = data_fit["OrdersInQueue"] + 1

# %%
data_fit["OrdersInQueue_plus1"].head()
# Out:
# Series([], Name: OrdersInQueue_plus1, dtype: int64)

# %%
data_fit["OrdersInQueue"].head()
# Out:
# Series([], Name: OrdersInQueue, dtype: int64)

# %%
data_val_fit["OrdersInQueue_plus1"] = data_val_fit["OrdersInQueue"]

# %%
# removed DriversClockedIn
# Bring back ClockedInEmployees
# change delivery type to string
# Add StoreId, changed to string 
# Add number 1 to OrdersInQueue

model_q2 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + \
                    DriversOnTheWay + ClockedInEmployees + StoreId', data=dt_train).fit()

predictions_q2 = model_q2.predict(data_val_fit)
data_val_fit["predictions_q2"] = predictions_q2
data_val_fit["error_q2"] = data_val_fit["ActualOrderCompletionTime"] - data_val_fit["predictions_q2"]
data_val_fit["error_q2_abs"] = np.abs(data_val_fit["error_q2"])
data_val_fit["error_q2_sqr"] = data_val_fit["error_q2"] ** 2
print(data_val_fit["error_q2_abs"].mean(), np.sqrt(data_val_fit["error_q2_sqr"].mean()))
# Out:
# 708.7251541237434 1470.7454925286468

# %%
print(model_q2.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     ActualOrderCompletionTime   R-squared:                       0.110
# Model:                                   OLS   Adj. R-squared:                  0.110
# Method:                        Least Squares   F-statistic:                     2040.
# Date:                       Sat, 17 Oct 2020   Prob (F-statistic):               0.00
# Time:                               15:39:45   Log-Likelihood:            -1.2931e+06
# No. Observations:                     148416   AIC:                         2.586e+06
# Df Residuals:                         148406   BIC:                         2.586e+06
# Df Model:                                  9
# Covariance Type:                   nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               2047.7724     16.382    125.001      0.000    2015.664    2079.881
# OrderPrice                15.1123      0.352     42.959      0.000      14.423      15.802
# DeliveryType            -469.9295      6.787    -69.241      0.000    -483.232    -456.627
# OrdersInQueue             99.4366      1.639     60.682      0.000      96.225     102.648
# OvenProductsInQueue       -0.3894      0.044     -8.777      0.000      -0.476      -0.302
# OrdersInOven              38.9873      3.238     12.041      0.000      32.641      45.333
# OrdersReadyForDispatch    64.0155      2.171     29.486      0.000      59.760      68.271
# DriversOnTheWay           48.0412      2.659     18.069      0.000      42.830      53.252
# ClockedInEmployees       -32.8724      1.510    -21.764      0.000     -35.833     -29.912
# StoreId                   -1.4604      0.069    -21.138      0.000      -1.596      -1.325
# ==============================================================================
# Omnibus:                   229993.254   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        171980521.906
# Skew:                           9.784   Prob(JB):                         0.00
# Kurtosis:                     168.613   Cond. No.                         579.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
dt_test = pd.read_csv("data_test.csv")

# %%
dt_test.head()
# Out:
#                                                                                        0
# 350653 194 9.99  1 0 0  0 0 3 1 5 2018-09-30 21:22:46 2018-09-30 21:56:23  480.0  1739.0
# 350654 176 7.99  1 0 0  2 0 2 1 4 2018-09-30 21:22:47 2018-09-30 21:49:11  420.0  1739.0
# 350655 159 3.99  2 4 12 3 0 7 0 8 2018-09-30 21:22:48 2018-09-30 21:32:15 -1.0     792.0
# 350656 176 13.99 1 1 2  2 0 2 1 4 2018-09-30 21:22:48 2018-09-30 21:49:11  120.0  1739.0
# 350659 121 9.95  1 2 8  0 2 3 1 4 2018-09-30 21:23:24 2018-09-30 21:45:04  360.0  1739.0

# %%
model_q3 = smf.ols('ActualOrderCompletionTime ~ OrderPrice + DeliveryType + OrdersInQueue + \
                    OvenProductsInQueue + OrdersInOven + OrdersReadyForDispatch + DriversClockedIn + \
                    DriversOnTheWay + ClockedInEmployees', data=dt_train).fit()
predictions_q3 = model_q3.predict(data_val_fit)

# %%
dt_test["predictions_q3"] = predictions_q3

# %%
dt_test["predictions_q3"].head()
# Out:
# 350653  194  9.99   1  0  0   0  0  3  1  5  2018-09-30 21:22:46  2018-09-30 21:56:23   480.0   NaN
# 350654  176  7.99   1  0  0   2  0  2  1  4  2018-09-30 21:22:47  2018-09-30 21:49:11   420.0   NaN
# 350655  159  3.99   2  4  12  3  0  7  0  8  2018-09-30 21:22:48  2018-09-30 21:32:15  -1.0     NaN
# 350656  176  13.99  1  1  2   2  0  2  1  4  2018-09-30 21:22:48  2018-09-30 21:49:11   120.0   NaN
# 350659  121  9.95   1  2  8   0  2  3  1  4  2018-09-30 21:23:24  2018-09-30 21:45:04   360.0   NaN
# Name: predictions_q3, dtype: float64

# %%
dt_test["predictions_q3"].to_csv("submission_q3.csv", index=True)
